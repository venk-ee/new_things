# %%
# how cani solve or implement ml solution 

#problem defination: 
#data
#eval
#features (what do i know ablut data ??)
#modelling (train,test,val),choosing a model,tunning,comparision of models 
    #tunnung - ie hyper param tunning 
#experimentation

# %%
import pandas as pd

# %%
df=pd.read_csv("./data/heart-disease.csv")

# %%
df.head(3)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1

# %%
df.target.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='target'>
